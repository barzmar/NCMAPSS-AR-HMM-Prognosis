# %% [markdown]
# # Load Data
# Load data already partly pre-processed in matlab.

# %%
from scipy.io import loadmat
import numpy as np

# %%
data = loadmat('..\dataNew\ppData.mat')

# %%
data_keys = data.keys()
print("Keys: %s" % data_keys)

wait = input("Press Enter to continue...")
print(data)
# Out:
# Keys: dict_keys(['__header__', '__version__', '__globals__', 'ppCruiseData', 'unitsFlights', '__function_workspace__'])
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Fri Aug 29 19:04:47 2025', '__version__': '1.0', '__globals__': [], 'ppCruiseData': array([[(array([[(array([[(array([[1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#                                 1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#                                [1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#                                 1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#                                [2.00000000e+00, 2.00000000e+00, 2.00000000e+00, ...,
#                                 2.00000000e+00, 2.00000000e+00, 2.00000000e+00],
#                                ...,
#                                [2.11912498e+03, 2.11559778e+03, 2.11206913e+03, ...,
#                                 2.01528018e+03, 1.99279275e+03, 1.96954539e+03],
# ...

# %%
ppCruiseData = data["ppCruiseData"]  # Example of accessing a specific key in the loaded data
ppCruiseData_shape = ppCruiseData.shape
print("Shape of ppCruiseData: %s" % str(ppCruiseData_shape))
ppCruiseData_sample = ppCruiseData[0]  # Accessing the first element
# print("Sample data from ppCruiseData: %s" % str(ppCruiseData_sample))
flight = ppCruiseData[0][0][0]  # Accessing nested data
# print("Flight data: %s" % str(flight))
# Further processing can be done based on the structure of the loaded data
h = flight.shape
print("h: %s" % str(h))
p = flight[0][0]
print("p: %s" % str(p))
print(str(np.shape(p)))
print("Tipo di p:", type(p))
if hasattr(p, 'item'):
    p_val = p.item()
    riddled = p_val[0]
    
    print("Tipo di p_val:", type(p_val[0]))

    p_array = p_val[0]

    print("Tipo di p_array:", type(p_array))
    p_array_shape = np.shape(p_array)
    print("Shape di p_array:", p_array_shape)
    p_array_array = p_array[0]
    print("Tipo di p_array_array:", type(p_array_array))
    p_array_array_shape = np.shape(p_array_array)
    print("Shape di p_array_array:", p_array_array_shape)
    p_array_array_0 = p_array_array[0]
    print("Tipo di p_array_array_0:", type(p_array_array_0))
    p_array_array_0_shape = np.shape(p_array_array_0)
    print("Shape di p_array_array_0:", p_array_array_0_shape)

    p_array_array_0_0 = p_array_array_0[0]
    print("Tipo di p_array_array_0_0:", type(p_array_array_0_0))
    p_array_array_0_0_shape = np.shape(p_array_array_0_0)
    print("Shape di p_array_array_0_0:", p_array_array_0_0_shape)
# Out:
# Shape of ppCruiseData: (1, 10)
# h: (1, 56)
# p: (array([[(array([[1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#                 1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#                [1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#                 1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#                [2.00000000e+00, 2.00000000e+00, 2.00000000e+00, ...,
#                 2.00000000e+00, 2.00000000e+00, 2.00000000e+00],
#                ...,
#                [2.11912498e+03, 2.11559778e+03, 2.11206913e+03, ...,
#                 2.01528018e+03, 1.99279275e+03, 1.96954539e+03],
#                [8.33637370e+03, 8.33114294e+03, 8.32654881e+03, ...,
#                 8.18221178e+03, 8.14810248e+03, 8.12204931e+03],
#                [2.47455441e+00, 2.45908951e+00, 2.44882505e+00, ...,
#                 2.05814066e+00, 1.94429768e+00, 1.92485545e+00]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
# ...
